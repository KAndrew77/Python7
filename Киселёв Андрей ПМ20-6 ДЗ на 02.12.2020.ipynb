# %%
import requests
import pprint
import datetime
from bs4 import BeautifulSoup




today = datetime.date.today()

base_url = 'https://kinoteatr.ru'
r = requests.get(f'{base_url}/raspisanie-kinoteatrov/')
soap = BeautifulSoup(r.text, 'lxml')
cinemas = []
for i in soap.findAll('div', class_='col-md-12 cinema_card'):
    name = i.find('h3').text.strip()
    href = i.find('a')['href'].strip()
    address = i.findAll('span', class_= 'sub_title')[0].text.strip()
    cinemas.append({
        'name': name,
        'href': href,
        'address': address
    })

    
shedule_dic = {}    
for i in range(7):
    date = today + datetime.timedelta(days=i)
    day = date.strftime('%d')
    month = date.strftime('%m')
    year = date.strftime('%y')
    

    
    allfilms = {}    
    for ind, cinema in enumerate(cinemas):
        r = requests.get(cinema['href'] + f"/?date={year}-{month}-{day}")
        soap = BeautifulSoup(r.text, 'lxml')
        films = soap.findAll('div', class_='shedule_movie bordered gtm_movie')
        films_dict = []
        for film in films:

            film_itself = {
                'name':film['data-gtm-list-item-filmname'],
                'href': film.find('a', class_='gtm-ec-list-item-movie')['href'],
                'format': film['data-gtm-format'],
                'genre': film['data-gtm-list-item-genre'],
                'raiting_sub': film.findAll('i', class_='raiting_sub')[0].text.strip(),
                "shedule": []
            }
            for time in film.findAll('a', class_="shedule_session"):
                film_itself["shedule"].append(time.find('span', class_='shedule_session_time').text.strip())

            

            films_dict.append(film_itself)    
        allfilms[cinema['name']] = films_dict
    shedule_dic[f"20{year}-{month}-{day}"] = allfilms
    
    
    
 
    
    
pprint.pprint(shedule_dic)     
 
# время компеляции около 20 сек
# Out:
# {'2020-12-18': {'КИНО ОККО Афимолл Сити': [{'format': '2d,imax',
#                                             'genre': 'мелодрама,приключения,фэнтези,экшн',
#                                             'href': 'https://kinoteatr.ru/film/serebryanye-konki-2/?cinema_prio=46',
#                                             'name': 'Серебряные коньки',
#                                             'raiting_sub': '6+',
#                                             'shedule': ['21:50',
#                                                         '22:50',
#                                                         '00:40']},
#                                            {'format': '2d',
#                                             'genre': 'комедия',
#                                             'href': 'https://kinoteatr.ru/film/obratnaya-svyaz-2/?cinema_prio=46',
#                                             'name': 'Обратная связь',
#                                             'raiting_sub': '16+',
#                                             'shedule': ['22:20',
#                                                         '23:25',
#                                                         '00:30']},
#                                            {'format': '2d',
#                                             'genre': 'комедия',
#                                             'href': 'https://kinoteatr.ru/film/realnye-pacany-protiv-zombi-2/?cinema_prio=46',
#                                             'name': 'Реальные пацаны против '
#                                                     'зомби',
#                                             'raiting_sub': '16+',
#                                             'shedule': ['22:45', '00:45']},
#                                            {'format': '2d',
#                                             'genre': 'хоррор',
#                                             'href': 'https://kinoteatr.ru/film/dibbuk-2/?cinema_prio=46',
#                                             'name': 'Диббук',
#                                             'raiting_sub': '18+',
#                                             'shedule': ['23:00', '00:55']},
#                                            {'format': '2d',
#                                             'genre': 'хоррор',
#                                             'href': 'https://kinoteatr.ru/film/the-call/?cinema_prio=46',
#                                             'name': 'Проклятие Лауры. '
#                                                     'Завещание',
#                                             'raiting_sub': '18+',
#                                             'shedule': ['21:55']},
#                                            {'format': '2d',
#                                             'genre': 'триллер',
#                                             'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=46',
#                                             'name': 'Взаперти',
#                                             'raiting_sub': '16+',
#                                             'shedule': ['23:25']},
#                                            {'format': '2d',
#                                             'genre': 'драма',
#                                             'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=46',
#                                             'name': 'Еще по одной',
#                                             'raiting_sub': '18+',
#                                             'shedule': ['23:50']},
#                                            {'format': '2d',
#                                             'genre': 'хоррор',
#                                             'href': 'https://kinoteatr.ru/film/zvonok-poslednyaya-glava-2/?cinema_prio=46',
#                                             'name': 'Звонок. Последняя глава',
#                                             'raiting_sub': '18+',
#                                             'shedule': ['00:00']},
#                                            {'format': '2d',
#                                             'genre': 'боевик,комедия',
#                                             'href': 'https://kinoteatr.ru/film/iskusstvennyy-intellekt-2/?cinema_prio=46',
#                                             'name': 'Искусственный интеллект',
#                                             'raiting_sub': '16+',
#                                             'shedule': ['00:55']},
#                                            {'format': '2d,4dx',
#                                             'genre': 'боевик,триллер,фантастика',
#                                             'href': 'https://kinoteatr.ru/film/dovod/?cinema_prio=46',
#                                             'name': 'Довод',
#                                             'raiting_sub': '16+',
#                                             'shedule': ['22:00']}],
#                 'Кино Оkkо Щёлковский': [{'format': 'imax,2d',
#                                           'genre': 'мелодрама,приключения,фэнтези,экшн',
#                                           'href': 'https://kinoteatr.ru/film/serebryanye-konki-2/?cinema_prio=89',
#                                           'name': 'Серебряные коньки',
#                                           'raiting_sub': '6+',
#                                           'shedule': ['21:35',
#                                                       '22:35',
#                                                       '23:25',
#                                                       '00:25']},
#                                          {'format': '2d',
#                                           'genre': 'комедия',
#                                           'href': 'https://kinoteatr.ru/film/obratnaya-svyaz-2/?cinema_prio=89',
#                                           'name': 'Обратная связь',
#                                           'raiting_sub': '16+',
#                                           'shedule': ['21:25', '23:30']},
#                                          {'format': '2d',
#                                           'genre': 'комедия',
#                                           'href': 'https://kinoteatr.ru/film/realnye-pacany-protiv-zombi-2/?cinema_prio=89',
#                                           'name': 'Реальные пацаны против '
#                                                   'зомби',
#                                           'raiting_sub': '16+',
#                                           'shedule': ['23:10']},
#                                          {'format': '2d',
#                                           'genre': 'драма,криминал,триллер',
#                                           'href': 'https://kinoteatr.ru/film/krovnye-uzy/?cinema_prio=89',
#                                           'name': 'Кровные узы',
#                                           'raiting_sub': '18+',
#                                           'shedule': ['23:15']}],
#                 'Кронверк Синема Вэйпарк': [{'format': '2d',
#                                              'genre': 'комедия',
#                                              'href': 'https://kinoteatr.ru/film/obratnaya-svyaz-2/?cinema_prio=43',
#                                              'name': 'Обратная связь',
#                                              'raiting_sub': '16+',
#                                              'shedule': ['21:45',
#                                                          '22:45',
#                                                          '23:55',
#                                                          '00:55']},
#                                             {'format': 'imax,2d',
#                                              'genre': 'мелодрама,приключения,фэнтези,экшн',
#                                              'href': 'https://kinoteatr.ru/film/serebryanye-konki-2/?cinema_prio=43',
#                                              'name': 'Серебряные коньки',
#                                              'raiting_sub': '6+',
#                                              'shedule': ['21:50',
#                                                          '22:55',
#                                                          '00:40']},
#                                             {'format': '2d',
#                                              'genre': 'комедия',
#                                              'href': 'https://kinoteatr.ru/film/realnye-pacany-protiv-zombi-2/?cinema_prio=43',
#                                              'name': 'Реальные пацаны против '
#                                                      'зомби',
#                                              'raiting_sub': '16+',
#                                              'shedule': ['22:20', '00:25']},
#                                             {'format': '2d',
#                                              'genre': 'хоррор',
#                                              'href': 'https://kinoteatr.ru/film/the-call/?cinema_prio=43',
#                                              'name': 'Проклятие Лауры. '
#                                                      'Завещание',
#                                              'raiting_sub': '18+',
#                                              'shedule': ['22:00']},
#                                             {'format': '2d',
#                                              'genre': 'драма',
#                                              'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=43',
#                                              'name': 'Еще по одной',
#                                              'raiting_sub': '18+',
#                                              'shedule': ['23:00']},
#                                             {'format': '2d',
#                                              'genre': 'хоррор',
#                                              'href': 'https://kinoteatr.ru/film/zvonok-poslednyaya-glava-2/?cinema_prio=43',
#                                              'name': 'Звонок. Последняя глава',
#                                              'raiting_sub': '18+',
#                                              'shedule': ['23:30']},
#                                             {'format': '2d',
#                                              'genre': 'боевик,фантастика',
#                                              'href': 'https://kinoteatr.ru/film/bresh/?cinema_prio=43',
#                                              'name': 'Брешь',
#                                              'raiting_sub': '18+',
#                                              'shedule': ['21:30']},
#                                             {'format': '2d',
#                                              'genre': 'хоррор',
#                                              'href': 'https://kinoteatr.ru/film/dibbuk-2/?cinema_prio=43',
#                                              'name': 'Диббук',
#                                              'raiting_sub': '18+',
#                                              'shedule': ['23:35']},
#                                             {'format': '2d',
#                                              'genre': 'драма,криминал,триллер',
#                                              'href': 'https://kinoteatr.ru/film/krovnye-uzy/?cinema_prio=43',
#                                              'name': 'Кровные узы',
#                                              'raiting_sub': '18+',
#                                              'shedule': ['00:05']}],
#                 'Кронверк Синема Облака': [{'format': '2d',
#                                             'genre': 'комедия',
#                                             'href': 'https://kinoteatr.ru/film/obratnaya-svyaz-2/?cinema_prio=45',
#                                             'name': 'Обратная связь',
#                                             'raiting_sub': '16+',
#                                             'shedule': ['22:15',
#                                                         '23:35',
#                                                         '00:20']},
#                                            {'format': '2d,imax',
#                                             'genre': 'мелодрама,приключения,фэнтези,экшн',
#                                             'href': 'https://kinoteatr.ru/film/serebryanye-konki-2/?cinema_prio=45',
#                                             'name': 'Серебряные коньки',
#                                             'raiting_sub': '6+',
#                                             'shedule': ['22:20', '23:30']},
#                                            {'format': '2d',
#                                             'genre': 'комедия',
#                                             'href': 'https://kinoteatr.ru/film/realnye-pacany-protiv-zombi-2/?cinema_prio=45',
#                                             'name': 'Реальные пацаны против '
#                                                     'зомби',
#                                             'raiting_sub': '16+',
#                                             'shedule': ['21:45', '23:50']},
#                                            {'format': '2d',
#                                             'genre': 'триллер',
#                                             'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=45',
#                                             'name': 'Взаперти',
#                                             'raiting_sub': '16+',
#                                             'shedule': ['00:30']},
#                                            {'format': '2d',
#                                             'genre': 'комедия,приключения',
#                                             'href': 'https://kinoteatr.ru/film/neposredstvenno-kaha/?cinema_prio=45',
#                                             'name': 'Непосредственно Каха',
#                                             'raiting_sub': '16+',
#                                             'shedule': ['22:50']},
#                                            {'format': '2d',
#                                             'genre': 'хоррор',
#                                             'href': 'https://kinoteatr.ru/film/dibbuk-2/?cinema_prio=45',
#                                             'name': 'Диббук',
#                                             'raiting_sub': '18+',
#                                             'shedule': ['22:35']}],
#                 'Кронверк Синема Семеновский': [{'format': '2d',
#                                                  'genre': 'комедия',
#                                                  'href': 'https://kinoteatr.ru/film/obratnaya-svyaz-2/?cinema_prio=47',
#                                                  'name': 'Обратная связь',
#                                                  'raiting_sub': '16+',
#                                                  'shedule': ['22:20',
#                                                              '23:30',
#                                                              '00:30']},
#                                                 {'format': '2d',
#                                                  'genre': 'комедия',
#                                                  'href': 'https://kinoteatr.ru/film/realnye-pacany-protiv-zombi-2/?cinema_prio=47',
#                                                  'name': 'Реальные пацаны '
#                                                          'против зомби',
#                                                  'raiting_sub': '16+',
#                                                  'shedule': ['22:35', '00:40']},
#                                                 {'format': 'imax,2d',
#                                                  'genre': 'мелодрама,приключения,фэнтези,экшн',
#                                                  'href': 'https://kinoteatr.ru/film/serebryanye-konki-2/?cinema_prio=47',
#                                                  'name': 'Серебряные коньки',
#                                                  'raiting_sub': '6+',
#                                                  'shedule': ['21:30']},
#                                                 {'format': '2d',
#                                                  'genre': 'драма',
#                                                  'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=47',
#                                                  'name': 'Еще по одной',
#                                                  'raiting_sub': '18+',
#                                                  'shedule': ['22:50']},
#                                                 {'format': '2d',
#                                                  'genre': 'хоррор',
#                                                  'href': 'https://kinoteatr.ru/film/dibbuk-2/?cinema_prio=47',
#                                                  'name': 'Диббук',
#                                                  'raiting_sub': '18+',
#                                                  'shedule': ['00:20']}],
#                 'Синема ПАРК Теплый стан': [{'format': '2d',
#                                              'genre': 'комедия',
#                                              'href': 'https://kinoteatr.ru/film/obratnaya-svyaz-2/?cinema_prio=21',
#                                              'name': 'Обратная связь',
#                                              'raiting_sub': '16+',
#                                              'shedule': ['21:30',
#                                                          '22:35',
#                                                          '23:40',
#                                                          '00:45']},
#                                             {'format': '2d,imax',
#                                              'genre': 'мелодрама,приключения,фэнтези,экшн',
#                                              'href': 'https://kinoteatr.ru/film/serebryanye-konki-2/?cinema_prio=21',
#                                              'name': 'Серебряные коньки',
#                                              'raiting_sub': '6+',
#                                              'shedule': ['21:35',
#                                                          '22:40',
#                                                          '00:25']},
#                                             {'format': '2d',
#                                              'genre': 'комедия',
#                                              'href': 'https://kinoteatr.ru/film/realnye-pacany-protiv-zombi-2/?cinema_prio=21',
#                                              'name': 'Реальные пацаны против '
#                                                      'зомби',
#                                              'raiting_sub': '16+',
#                                              'shedule': ['22:20',
#                                                          '23:25',
#                                                          '00:25']},
#                                             {'format': '2d',
#                                              'genre': 'хоррор',
#                                              'href': 'https://kinoteatr.ru/film/the-call/?cinema_prio=21',
#                                              'name': 'Проклятие Лауры. '
#                                                      'Завещание',
#                                              'raiting_sub': '18+',
#                                              'shedule': ['22:05', '00:10']},
#                                             {'format': '2d',
#                                              'genre': 'хоррор',
#                                              'href': 'https://kinoteatr.ru/film/zvonok-poslednyaya-glava-2/?cinema_prio=21',
#                                              'name': 'Звонок. Последняя глава',
#                                              'raiting_sub': '18+',
#                                              'shedule': ['23:10', '00:30']},
#                                             {'format': '2d',
#                                              'genre': 'драма',
#                                              'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=21',
#                                              'name': 'Еще по одной',
#                                              'raiting_sub': '18+',
#                                              'shedule': ['23:35']},
#                                             {'format': '2d',
#                                              'genre': 'боевик,фантастика',
#                                              'href': 'https://kinoteatr.ru/film/bresh/?cinema_prio=21',
#                                              'name': 'Брешь',
#                                              'raiting_sub': '18+',
#                                              'shedule': ['21:40']},
#                                             {'format': '2d',
#                                              'genre': 'хоррор',
#                                              'href': 'https://kinoteatr.ru/film/dibbuk-2/?cinema_prio=21',
#                                              'name': 'Диббук',
#                                              'raiting_sub': '18+',
#                                              'shedule': ['23:45']},
#                                             {'format': '2d',
#                                              'genre': 'ужасы,фантастика',
#                                              'href': 'https://kinoteatr.ru/film/gran-vremeni/?cinema_prio=21',
#                                              'name': 'Грань времени',
#                                              'raiting_sub': '18+',
#                                              'shedule': ['22:15']}],
#                 'Синема Парк Бутово Молл': [{'format': '2d',
#                                              'genre': 'комедия',
#                                              'href': 'https://kinoteatr.ru/film/obratnaya-svyaz-2/?cinema_prio=79',
#                                              'name': 'Обратная связь',
#                                              'raiting_sub': '16+',
#                                              'shedule': ['21:40',
#                                                          '22:40',
#                                                          '23:50',
#                                                          '00:50']},
#                                             {'format': '2d',
#                                              'genre': 'комедия',
#                                              'href': 'https://kinoteatr.ru/film/realnye-pacany-protiv-zombi-2/?cinema_prio=79',
#                                              'name': 'Реальные пацаны против '
#                                                      'зомби',
#                                              'raiting_sub': '16+',
#                                              'shedule': ['22:10',
#                                                          '23:10',
#                                                          '00:15',
#                                                          '01:15']},
#                                             {'format': 'imax,2d',
#                                              'genre': 'мелодрама,приключения,фэнтези,экшн',
#                                              'href': 'https://kinoteatr.ru/film/serebryanye-konki-2/?cinema_prio=79',
#                                              'name': 'Серебряные коньки',
#                                              'raiting_sub': '6+',
#                                              'shedule': ['21:35',
#                                                          '22:40',
#                                                          '00:25']},
#                                             {'format': '2d',
#                                              'genre': 'хоррор',
#                                              'href': 'https://kinoteatr.ru/film/zvonok-poslednyaya-glava-2/?cinema_prio=79',
#                                              'name': 'Звонок. Последняя глава',
#                                              'raiting_sub': '18+',
#                                              'shedule': ['21:55', '00:05']},
#                                             {'format': '2d',
#                                              'genre': 'хоррор',
#                                              'href': 'https://kinoteatr.ru/film/the-call/?cinema_prio=79',
#                                              'name': 'Проклятие Лауры. '
#                                                      'Завещание',
#                                              'raiting_sub': '18+',
#                                              'shedule': ['22:20']},
#                                             {'format': '2d',
#                                              'genre': 'хоррор',
#                                              'href': 'https://kinoteatr.ru/film/dibbuk-2/?cinema_prio=79',
#                                              'name': 'Диббук',
#                                              'raiting_sub': '18+',
#                                              'shedule': ['00:30']},
#                                             {'format': '2d',
#                                              'genre': 'хоррор',
#                                              'href': 'https://kinoteatr.ru/film/proklyatie-monahini-rouz-2/?cinema_prio=79',
#                                              'name': 'Проклятие монахини Роуз',
#                                              'raiting_sub': '18+',
#                                              'shedule': ['23:35']}],
#                 'Синема Парк Глобал Сити на Южной': [{'format': '2d',
#                                                       'genre': 'комедия',
#                                                       'href': 'https://kinoteatr.ru/film/obratnaya-svyaz-2/?cinema_prio=7',
#                                                       'name': 'Обратная связь',
#                                                       'raiting_sub': '16+',
#                                                       'shedule': ['21:25',
#                                                                   '22:25',
#                                                                   '23:30',
#                                                                   '00:30']},
#                                                      {'format': 'imax,2d',
#                                                       'genre': 'мелодрама,приключения,фэнтези,экшн',
#                                                       'href': 'https://kinoteatr.ru/film/serebryanye-konki-2/?cinema_prio=7',
#                                                       'name': 'Серебряные '
#                                                               'коньки',
#                                                       'raiting_sub': '6+',
#                                                       'shedule': ['21:45',
#                                                                   '23:00',
#                                                                   '00:30']},
#                                                      {'format': '2d',
#                                                       'genre': 'комедия',
#                                                       'href': 'https://kinoteatr.ru/film/realnye-pacany-protiv-zombi-2/?cinema_prio=7',
#                                                       'name': 'Реальные пацаны '
#                                                               'против зомби',
#                                                       'raiting_sub': '16+',
#                                                       'shedule': ['22:50',
#                                                                   '00:50']},
#                                                      {'format': '2d',
#                                                       'genre': 'хоррор',
#                                                       'href': 'https://kinoteatr.ru/film/the-call/?cinema_prio=7',
#                                                       'name': 'Проклятие '
#                                                               'Лауры. '
#                                                               'Завещание',
#                                                       'raiting_sub': '18+',
#                                                       'shedule': ['21:55']},
#                                                      {'format': '2d',
#                                                       'genre': 'триллер',
#                                                       'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=7',
#                                                       'name': 'Взаперти',
#                                                       'raiting_sub': '16+',
#                                                       'shedule': ['23:35']},
#                                                      {'format': '2d',
#                                                       'genre': 'боевик,фантастика',
#                                                       'href': 'https://kinoteatr.ru/film/bresh/?cinema_prio=7',
#                                                       'name': 'Брешь',
#                                                       'raiting_sub': '18+',
#                                                       'shedule': ['21:35']},
#                                                      {'format': '2d',
#                                                       'genre': 'хоррор',
#                                                       'href': 'https://kinoteatr.ru/film/dibbuk-2/?cinema_prio=7',
#                                                       'name': 'Диббук',
#                                                       'raiting_sub': '18+',
#                                                       'shedule': ['00:00']},
#                                                      {'format': '2d',
#                                                       'genre': 'драма,криминал,триллер',
#                                                       'href': 'https://kinoteatr.ru/film/krovnye-uzy/?cinema_prio=7',
#                                                       'name': 'Кровные узы',
#                                                       'raiting_sub': '18+',
#                                                       'shedule': ['23:15']}],
#                 'Синема Парк Зеленопарк': [{'format': '2d,imax',
#                                             'genre': 'мелодрама,приключения,фэнтези,экшн',
#                                             'href': 'https://kinoteatr.ru/film/serebryanye-konki-2/?cinema_prio=37',
#                                             'name': 'Серебряные коньки',
#                                             'raiting_sub': '6+',
#                                             'shedule': ['21:40',
#                                                         '23:00',
#                                                         '00:30']},
#                                            {'format': '2d',
#                                             'genre': 'комедия',
#                                             'href': 'https://kinoteatr.ru/film/obratnaya-svyaz-2/?cinema_prio=37',
#                                             'name': 'Обратная связь',
#                                             'raiting_sub': '16+',
#                                             'shedule': ['21:45',
#                                                         '22:55',
#                                                         '23:55']},
#                                            {'format': '2d',
#                                             'genre': 'комедия',
#                                             'href': 'https://kinoteatr.ru/film/realnye-pacany-protiv-zombi-2/?cinema_prio=37',
#                                             'name': 'Реальные пацаны против '
#                                                     'зомби',
#                                             'raiting_sub': '16+',
#                                             'shedule': ['22:15',
#                                                         '23:20',
#                                                         '00:20']}],
#                 'Синема Парк МЕГА Химки': [{'format': 'imax,2d',
#                                             'genre': 'мелодрама,приключения,фэнтези,экшн',
#                                             'href': 'https://kinoteatr.ru/film/serebryanye-konki-2/?cinema_prio=22',
#                                             'name': 'Серебряные коньки',
#                                             'raiting_sub': '6+',
#                                             'shedule': ['21:45',
#                                                         '22:35',
#                                                         '23:30',
#                                                         '00:35']},
#                                            {'format': '2d',
#                                             'genre': 'комедия',
#                                             'href': 'https://kinoteatr.ru/film/obratnaya-svyaz-2/?cinema_prio=22',
#                                             'name': 'Обратная связь',
#                                             'raiting_sub': '16+',
#                                             'shedule': ['21:40',
#                                                         '22:40',
#                                                         '23:50',
#                                                         '00:50']},
#                                            {'format': '2d',
#                                             'genre': 'комедия',
#                                             'href': 'https://kinoteatr.ru/film/realnye-pacany-protiv-zombi-2/?cinema_prio=22',
#                                             'name': 'Реальные пацаны против '
#                                                     'зомби',
#                                             'raiting_sub': '16+',
#                                             'shedule': ['22:05',
#                                                         '23:10',
#                                                         '00:10']},
#                                            {'format': '2d',
#                                             'genre': 'хоррор',
#                                             'href': 'https://kinoteatr.ru/film/the-call/?cinema_prio=22',
#                                             'name': 'Проклятие Лауры. '
#                                                     'Завещание',
#                                             'raiting_sub': '18+',
#                                             'shedule': ['22:30', '00:40']},
#                                            {'format': '2d',
#                                             'genre': 'хоррор',
#                                             'href': 'https://kinoteatr.ru/film/zvonok-poslednyaya-glava-2/?cinema_prio=22',
#                                             'name': 'Звонок. Последняя глава',
#                                             'raiting_sub': '18+',
#                                             'shedule': ['21:30', '23:35']},
#                                            {'format': '2d',
#                                             'genre': 'триллер',
#                                             'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=22',
#                                             'name': 'Взаперти',
#                                             'raiting_sub': '16+',
#                                             'shedule': ['23:40']},
#                                            {'format': '2d',
#                                             'genre': 'боевик,фантастика',
#                                             'href': 'https://kinoteatr.ru/film/bresh/?cinema_prio=22',
#                                             'name': 'Брешь',
#                                             'raiting_sub': '18+',
#                                             'shedule': ['21:25']},
#                                            {'format': '2d',
#                                             'genre': 'хоррор',
#                                             'href': 'https://kinoteatr.ru/film/dibbuk-2/?cinema_prio=22',
#                                             'name': 'Диббук',
#                                             'raiting_sub': '18+',
#                                             'shedule': ['00:00']},
#                                            {'format': '2d',
#                                             'genre': 'хоррор',
#                                             'href': 'https://kinoteatr.ru/film/punkt-naznacheniya-akvapark/?cinema_prio=22',
#                                             'name': 'Пункт назначения. '
#                                                     'Аквапарк',
#                                             'raiting_sub': '18+',
#                                             'shedule': ['23:25']}],
#                 'Синема Парк Мега Белая Дача': [{'format': '2d',
#                                                  'genre': 'комедия',
#                                                  'href': 'https://kinoteatr.ru/film/obratnaya-svyaz-2/?cinema_prio=24',
#                                                  'name': 'Обратная связь',
#                                                  'raiting_sub': '16+',
#                                                  'shedule': ['21:40',
#                                                              '22:45',
#                                                              '23:50',
#                                                              '00:55']},
#                                                 {'format': '2d,imax',
#                                                  'genre': 'мелодрама,приключения,фэнтези,экшн',
#                                                  'href': 'https://kinoteatr.ru/film/serebryanye-konki-2/?cinema_prio=24',
#                                                  'name': 'Серебряные коньки',
#                                                  'raiting_sub': '6+',
#                                                  'shedule': ['21:40', '22:30']},
#                                                 {'format': '2d',
#                                                  'genre': 'комедия',
#                                                  'href': 'https://kinoteatr.ru/film/realnye-pacany-protiv-zombi-2/?cinema_prio=24',
#                                                  'name': 'Реальные пацаны '
#                                                          'против зомби',
#                                                  'raiting_sub': '16+',
#                                                  'shedule': ['22:10', '00:15']},
#                                                 {'format': '2d',
#                                                  'genre': 'хоррор',
#                                                  'href': 'https://kinoteatr.ru/film/the-call/?cinema_prio=24',
#                                                  'name': 'Проклятие Лауры. '
#                                                          'Завещание',
#                                                  'raiting_sub': '18+',
#                                                  'shedule': ['22:15', '00:20']},
#                                                 {'format': '2d',
#                                                  'genre': 'триллер',
#                                                  'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=24',
#                                                  'name': 'Взаперти',
#                                                  'raiting_sub': '16+',
#                                                  'shedule': ['23:45']},
#                                                 {'format': '2d',
#                                                  'genre': 'комедия,приключения',
#                                                  'href': 'https://kinoteatr.ru/film/neposredstvenno-kaha/?cinema_prio=24',
#                                                  'name': 'Непосредственно Каха',
#                                                  'raiting_sub': '16+',
#                                                  'shedule': ['21:30']},
#                                                 {'format': '2d',
#                                                  'genre': 'хоррор',
#                                                  'href': 'https://kinoteatr.ru/film/zvonok-poslednyaya-glava-2/?cinema_prio=24',
#                                                  'name': 'Звонок. Последняя '
#                                                          'глава',
#                                                  'raiting_sub': '18+',
#                                                  'shedule': ['21:45']},
#                                                 {'format': '2d',
#                                                  'genre': 'хоррор',
#                                                  'href': 'https://kinoteatr.ru/film/dibbuk-2/?cinema_prio=24',
#                                                  'name': 'Диббук',
#                                                  'raiting_sub': '18+',
#                                                  'shedule': ['23:10']},
#                                                 {'format': '2d,4dx',
#                                                  'genre': 'боевик,триллер,фантастика',
#                                                  'href': 'https://kinoteatr.ru/film/dovod/?cinema_prio=24',
#                                                  'name': 'Довод',
#                                                  'raiting_sub': '16+',
#                                                  'shedule': ['23:15']},
#                                                 {'format': '2d',
#                                                  'genre': 'хоррор',
#                                                  'href': 'https://kinoteatr.ru/film/proklyatie-monahini-rouz-2/?cinema_prio=24',
#                                                  'name': 'Проклятие монахини '
#                                                          'Роуз',
#                                                  'raiting_sub': '18+',
#                                                  'shedule': ['23:55']}],
#                 'Синема Парк Метрополис на Войковской': [{'format': '2d',
#                                                           'genre': 'комедия',
#                                                           'href': 'https://kinoteatr.ru/film/obratnaya-svyaz-2/?cinema_prio=26',
#                                                           'name': 'Обратная '
#                                                                   'связь',
#                                                           'raiting_sub': '16+',
#                                                           'shedule': ['21:30',
#                                                                       '22:00',
#                                                                       '22:40',
#                                                                       '23:40',
#                                                                       '00:10',
#                                                                       '00:50']},
#                                                          {'format': '2d,imax',
#                                                           'genre': 'мелодрама,приключения,фэнтези,экшн',
#                                                           'href': 'https://kinoteatr.ru/film/serebryanye-konki-2/?cinema_prio=26',
#                                                           'name': 'Серебряные '
#                                                                   'коньки',
#                                                           'raiting_sub': '6+',
#                                                           'shedule': ['21:55',
#                                                                       '23:15',
#                                                                       '00:45']},
#                                                          {'format': '2d',
#                                                           'genre': 'хоррор',
#                                                           'href': 'https://kinoteatr.ru/film/the-call/?cinema_prio=26',
#                                                           'name': 'Проклятие '
#                                                                   'Лауры. '
#                                                                   'Завещание',
#                                                           'raiting_sub': '18+',
#                                                           'shedule': ['22:05',
#                                                                       '00:10']},
#                                                          {'format': '2d',
#                                                           'genre': 'драма',
#                                                           'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=26',
#                                                           'name': 'Еще по '
#                                                                   'одной',
#                                                           'raiting_sub': '18+',
#                                                           'shedule': ['21:35',
#                                                                       '00:05']},
#                                                          {'format': '2d',
#                                                           'genre': 'комедия',
#                                                           'href': 'https://kinoteatr.ru/film/realnye-pacany-protiv-zombi-2/?cinema_prio=26',
#                                                           'name': 'Реальные '
#                                                                   'пацаны '
#                                                                   'против '
#                                                                   'зомби',
#                                                           'raiting_sub': '16+',
#                                                           'shedule': ['22:55']},
#                                                          {'format': '2d',
#                                                           'genre': 'хоррор',
#                                                           'href': 'https://kinoteatr.ru/film/zvonok-poslednyaya-glava-2/?cinema_prio=26',
#                                                           'name': 'Звонок. '
#                                                                   'Последняя '
#                                                                   'глава',
#                                                           'raiting_sub': '18+',
#                                                           'shedule': ['23:30']},
#                                                          {'format': '2d',
#                                                           'genre': 'хоррор',
#                                                           'href': 'https://kinoteatr.ru/film/dibbuk-2/?cinema_prio=26',
#                                                           'name': 'Диббук',
#                                                           'raiting_sub': '18+',
#                                                           'shedule': ['23:20']},
#                                                          {'format': '2d',
#                                                           'genre': 'боевик,комедия',
#                                                           'href': 'https://kinoteatr.ru/film/iskusstvennyy-intellekt-2/?cinema_prio=26',
#                                                           'name': 'Искусственный '
#                                                                   'интеллект',
#                                                           'raiting_sub': '16+',
#                                                           'shedule': ['21:25']},
#                                                          {'format': '2d,4dx',
# ...
#                                             'name': 'Серебряные коньки',
#                                             'raiting_sub': '6+',
#                                             'shedule': ['21:35',
#                                                         '22:35',
#                                                         '23:25',
#                                                         '00:25']},
#                                            {'format': '2d',
#                                             'genre': 'комедия',
#                                             'href': 'https://kinoteatr.ru/film/obratnaya-svyaz-2/?cinema_prio=53',
#                                             'name': 'Обратная связь',
#                                             'raiting_sub': '16+',
#                                             'shedule': ['21:25',
#                                                         '22:25',
#                                                         '23:30',
#                                                         '00:30']},
#                                            {'format': '2d',
#                                             'genre': 'комедия',
#                                             'href': 'https://kinoteatr.ru/film/realnye-pacany-protiv-zombi-2/?cinema_prio=53',
#                                             'name': 'Реальные пацаны против '
#                                                     'зомби',
#                                             'raiting_sub': '16+',
#                                             'shedule': ['22:50', '00:50']},
#                                            {'format': '2d',
#                                             'genre': 'триллер',
#                                             'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=53',
#                                             'name': 'Взаперти',
#                                             'raiting_sub': '16+',
#                                             'shedule': ['21:30']},
#                                            {'format': '2d',
#                                             'genre': 'драма,криминал,триллер',
#                                             'href': 'https://kinoteatr.ru/film/krovnye-uzy/?cinema_prio=53',
#                                             'name': 'Кровные узы',
#                                             'raiting_sub': '18+',
#                                             'shedule': ['23:25']}],
#                 'Формула Кино на Кутузовском': [{'format': '2d',
#                                                  'genre': 'комедия',
#                                                  'href': 'https://kinoteatr.ru/film/obratnaya-svyaz-2/?cinema_prio=49',
#                                                  'name': 'Обратная связь',
#                                                  'raiting_sub': '16+',
#                                                  'shedule': ['21:50',
#                                                              '22:50',
#                                                              '00:00',
#                                                              '00:55']},
#                                                 {'format': '2d,imax',
#                                                  'genre': 'мелодрама,приключения,фэнтези,экшн',
#                                                  'href': 'https://kinoteatr.ru/film/serebryanye-konki-2/?cinema_prio=49',
#                                                  'name': 'Серебряные коньки',
#                                                  'raiting_sub': '6+',
#                                                  'shedule': ['21:40', '22:45']},
#                                                 {'format': '2d',
#                                                  'genre': 'комедия',
#                                                  'href': 'https://kinoteatr.ru/film/realnye-pacany-protiv-zombi-2/?cinema_prio=49',
#                                                  'name': 'Реальные пацаны '
#                                                          'против зомби',
#                                                  'raiting_sub': '16+',
#                                                  'shedule': ['22:20', '00:25']},
#                                                 {'format': '2d',
#                                                  'genre': 'хоррор',
#                                                  'href': 'https://kinoteatr.ru/film/the-call/?cinema_prio=49',
#                                                  'name': 'Проклятие Лауры. '
#                                                          'Завещание',
#                                                  'raiting_sub': '18+',
#                                                  'shedule': ['23:45', '00:30']},
#                                                 {'format': '2d',
#                                                  'genre': 'хоррор',
#                                                  'href': 'https://kinoteatr.ru/film/zvonok-poslednyaya-glava-2/?cinema_prio=49',
#                                                  'name': 'Звонок. Последняя '
#                                                          'глава',
#                                                  'raiting_sub': '18+',
#                                                  'shedule': ['21:35', '23:40']},
#                                                 {'format': '2d',
#                                                  'genre': 'боевик,фантастика',
#                                                  'href': 'https://kinoteatr.ru/film/bresh/?cinema_prio=49',
#                                                  'name': 'Брешь',
#                                                  'raiting_sub': '18+',
#                                                  'shedule': ['00:35']},
#                                                 {'format': '2d',
#                                                  'genre': 'комедия',
#                                                  'href': 'https://kinoteatr.ru/film/neadekvatnye-lyudi-2-2/?cinema_prio=49',
#                                                  'name': 'Неадекватные люди 2',
#                                                  'raiting_sub': '16+',
#                                                  'shedule': ['21:55']}],
#                 'Формула Кино на Мичуринском': [{'format': '2d',
#                                                  'genre': 'комедия',
#                                                  'href': 'https://kinoteatr.ru/film/obratnaya-svyaz-2/?cinema_prio=50',
#                                                  'name': 'Обратная связь',
#                                                  'raiting_sub': '16+',
#                                                  'shedule': ['21:25',
#                                                              '22:25',
#                                                              '23:30',
#                                                              '00:30']},
#                                                 {'format': 'imax,2d',
#                                                  'genre': 'мелодрама,приключения,фэнтези,экшн',
#                                                  'href': 'https://kinoteatr.ru/film/serebryanye-konki-2/?cinema_prio=50',
#                                                  'name': 'Серебряные коньки',
#                                                  'raiting_sub': '6+',
#                                                  'shedule': ['21:45',
#                                                              '23:00',
#                                                              '00:30']},
#                                                 {'format': '2d',
#                                                  'genre': 'комедия',
#                                                  'href': 'https://kinoteatr.ru/film/realnye-pacany-protiv-zombi-2/?cinema_prio=50',
#                                                  'name': 'Реальные пацаны '
#                                                          'против зомби',
#                                                  'raiting_sub': '16+',
#                                                  'shedule': ['22:50', '00:50']},
#                                                 {'format': '2d',
#                                                  'genre': 'триллер',
#                                                  'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=50',
#                                                  'name': 'Взаперти',
#                                                  'raiting_sub': '16+',
#                                                  'shedule': ['22:45', '00:45']},
#                                                 {'format': '2d',
#                                                  'genre': 'хоррор',
#                                                  'href': 'https://kinoteatr.ru/film/the-call/?cinema_prio=50',
#                                                  'name': 'Проклятие Лауры. '
#                                                          'Завещание',
#                                                  'raiting_sub': '18+',
#                                                  'shedule': ['21:55']},
#                                                 {'format': '2d',
#                                                  'genre': 'драма',
#                                                  'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=50',
#                                                  'name': 'Еще по одной',
#                                                  'raiting_sub': '18+',
#                                                  'shedule': ['00:00']},
#                                                 {'format': '2d',
#                                                  'genre': 'боевик,фантастика',
#                                                  'href': 'https://kinoteatr.ru/film/bresh/?cinema_prio=50',
#                                                  'name': 'Брешь',
#                                                  'raiting_sub': '18+',
#                                                  'shedule': ['21:30']},
#                                                 {'format': '2d',
#                                                  'genre': 'драма,криминал,триллер',
#                                                  'href': 'https://kinoteatr.ru/film/krovnye-uzy/?cinema_prio=50',
#                                                  'name': 'Кровные узы',
#                                                  'raiting_sub': '18+',
#                                                  'shedule': ['23:40']}],
#                 'Формула Кино на Можайке': [{'format': '2d',
#                                              'genre': 'комедия',
#                                              'href': 'https://kinoteatr.ru/film/obratnaya-svyaz-2/?cinema_prio=57',
#                                              'name': 'Обратная связь',
#                                              'raiting_sub': '16+',
#                                              'shedule': ['22:30',
#                                                          '23:25',
#                                                          '00:40']},
#                                             {'format': '2d,imax',
#                                              'genre': 'мелодрама,приключения,фэнтези,экшн',
#                                              'href': 'https://kinoteatr.ru/film/serebryanye-konki-2/?cinema_prio=57',
#                                              'name': 'Серебряные коньки',
#                                              'raiting_sub': '6+',
#                                              'shedule': ['21:40', '23:40']},
#                                             {'format': '2d',
#                                              'genre': 'комедия',
#                                              'href': 'https://kinoteatr.ru/film/realnye-pacany-protiv-zombi-2/?cinema_prio=57',
#                                              'name': 'Реальные пацаны против '
#                                                      'зомби',
#                                              'raiting_sub': '16+',
#                                              'shedule': ['23:00', '00:25']},
#                                             {'format': '2d',
#                                              'genre': 'хоррор',
#                                              'href': 'https://kinoteatr.ru/film/dibbuk-2/?cinema_prio=57',
#                                              'name': 'Диббук',
#                                              'raiting_sub': '18+',
#                                              'shedule': ['22:20', '00:15']}],
#                 'Формула Кино на Полежаевской': [{'format': '2d',
#                                                   'genre': 'комедия',
#                                                   'href': 'https://kinoteatr.ru/film/realnye-pacany-protiv-zombi-2/?cinema_prio=56',
#                                                   'name': 'Реальные пацаны '
#                                                           'против зомби',
#                                                   'raiting_sub': '16+',
#                                                   'shedule': ['21:45',
#                                                               '22:50',
#                                                               '23:50',
#                                                               '00:55']},
#                                                  {'format': '2d',
#                                                   'genre': 'комедия',
#                                                   'href': 'https://kinoteatr.ru/film/obratnaya-svyaz-2/?cinema_prio=56',
#                                                   'name': 'Обратная связь',
#                                                   'raiting_sub': '16+',
#                                                   'shedule': ['21:30',
#                                                               '22:30',
#                                                               '23:40',
#                                                               '00:40']},
#                                                  {'format': '2d,imax',
#                                                   'genre': 'мелодрама,приключения,фэнтези,экшн',
#                                                   'href': 'https://kinoteatr.ru/film/serebryanye-konki-2/?cinema_prio=56',
#                                                   'name': 'Серебряные коньки',
#                                                   'raiting_sub': '6+',
#                                                   'shedule': ['21:55',
#                                                               '22:55',
#                                                               '00:45']},
#                                                  {'format': '2d',
#                                                   'genre': 'хоррор',
#                                                   'href': 'https://kinoteatr.ru/film/the-call/?cinema_prio=56',
#                                                   'name': 'Проклятие Лауры. '
#                                                           'Завещание',
#                                                   'raiting_sub': '18+',
#                                                   'shedule': ['22:45',
#                                                               '00:50']},
#                                                  {'format': '2d',
#                                                   'genre': 'криминальная '
#                                                            'комедия',
#                                                   'href': 'https://kinoteatr.ru/film/kriminalnye-bossy/?cinema_prio=56',
#                                                   'name': 'Криминальные боссы',
#                                                   'raiting_sub': '18+',
#                                                   'shedule': ['23:05']}]}}
